# %%
cat << 'EOF' > notebooks/generate_eda.py
import json

notebook_content = {
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# 📈 Task 2: Exploratory Data Analysis (EDA) - Financial Inclusion\n",
    "### Comprehensive historical profile mapping Ethiopia's structural access growth metrics."
   ]
  },
  {
   "cell_type": "code",
   "execution_count": None,
   "metadata": {},
   "outputs": [],
   "source": [
    "import pandas as pd\n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "\n",
    "# Load clean analytical tracking database matrix\n",
    "df = pd.read_csv('../data/processed/cleaned_unified_data.csv')\n",
    "print(f'Total observations loaded: {len(df)}')\n",
    "df.head()"
   ]
  },
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "### 📊 Distribution Analysis of Schema Row Variables"
   ]
  },
  {
   "cell_type": "code",
   "execution_count": None,
   "metadata": {},
   "outputs": [],
   "source": [
    "plt.figure(figsize=(8, 4))\n",
    "sns.countplot(data=df, x='record_type', palette='viridis')\n",
    "plt.title('Dataset Record Stratification Profile')\n",
    "plt.xlabel('Unified Component Row Metric')\n",
    "plt.ylabel('Total Entity Observations')\n",
    "plt.show()"
   ]
  }
 ],
 "metadata": {
  "language_info": {
   "name": "python"
  }
 },
 "nbformat": 4,
 "nbformat_minor": 2
}

with open("notebooks/exploratory_analysis.ipynb", "w") as f:
    json.dump(notebook_content, f, indent=1)

print("[Success] Automated EDA Jupyter Notebook structural asset injected!")
EOF
python notebooks/generate_eda.py && rm notebooks/generate_eda.py
